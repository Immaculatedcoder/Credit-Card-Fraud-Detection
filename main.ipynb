# %%
from src.data_processor import TransactionDataProcessor
import logging

logging.basicConfig(level=logging.INFO)

def main():
    processor = TransactionDataProcessor("data/creditcard_20023.csv")
    df = processor.load_data()
    print(df.head())

if __name__ == "__main__":
    main()
# Out:
# ERROR:src.data_processor:File not found: data/creditcard_20023.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 12
#       9     print(df.head())
#      11 if __name__ == "__main__":
# ---> 12     main()
#
# Cell In[5], line 8, in main()
#       6 def main():
#       7     processor = TransactionDataProcessor("data/creditcard_20023.csv")
# ----> 8     df = processor.load_data()
#       9     print(df.head())
#
# File c:\Users\adeba\OneDrive\Desktop\Credit Card\Credit-Card-Fraud-Detection\src\data_processor.py:39, in TransactionDataProcessor.load_data(self)
#      35 """
#      36 Instance Method1: We want to convert that .csv to dataframe
#      37 """
#      38 try:
# ---> 39     self.raw_data = pd.read_csv(self.csv_path)
#      40     logger.info(f"Loaded {len(self.raw_data)} transactions from {self.csv_path}")
# ...

# %% [markdown]
# Load Dataset and Get Idea of the Data

# %%
credit_card_transactions = pd.read_csv("data/creditcard_2023.csv")
credit_card_transactions.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...
